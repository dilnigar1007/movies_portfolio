# %%
import pandas as pd
import numpy as np
import re

# %%
file_dir = 'C:/Users/saint/OneDrive/Desktop/DataClass/movies_portfolio'

# %%
f'{file_dir}title-crew'
# Out:
# 'C:/Users/saint/OneDrive/Desktop/DataClass/movies_portfoliotitle-crew'

# %%
crew=pd.read_table(f'{file_dir}/title-crew.tsv')

# %%
crew.head()
# Out:
#       tconst  directors writers
# 0  tt0000001  nm0005690      \N
# 1  tt0000002  nm0721526      \N
# 2  tt0000003  nm0721526      \N
# 3  tt0000004  nm0721526      \N
# 4  tt0000005  nm0005690      \N

# %%
metadata=pd.read_table(f'{file_dir}/title-metadata.tsv', low_memory=False)

# %%
ratings=pd.read_table(f'{file_dir}/title-ratings.tsv')

# %%
metadata.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes genres
# 0       0      1894      \N              1     \N
# 1       0      1892      \N              5     \N
# 2       0      1892      \N              4     \N
# 3       0      1892      \N             12     \N
# 4       0      1893      \N              1     \N

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1914
# 1  tt0000002            5.8       259
# 2  tt0000003            6.5      1720
# 3  tt0000004            5.6       172
# 4  tt0000005            6.2      2537

# %%
metadata.tail()
# Out:
#             tconst  titleType               primaryTitle  \
# 9275709  tt9916848  tvEpisode              Episode #3.17
# 9275710  tt9916850  tvEpisode              Episode #3.19
# 9275711  tt9916852  tvEpisode              Episode #3.20
# 9275712  tt9916856      short                   The Wind
# 9275713  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 9275709              Episode #3.17       0      2010      \N             \N
# 9275710              Episode #3.19       0      2010      \N             \N
# 9275711              Episode #3.20       0      2010      \N             \N
# 9275712                   The Wind       0      2015      \N             27
# 9275713  Horrid Henry Knows It All       0      2014      \N             10
#
#         genres
# 9275709     \N
# 9275710     \N
# 9275711     \N
# 9275712     \N
# 9275713     \N

# %%
ratings.tail()
# Out:
#             tconst  averageRating  numVotes
# 1048570  tt5217194            7.2        19
# 1048571  tt5217198            5.1        64
# 1048572  tt5217254            8.1        32
# 1048573  tt5217256            7.3       151
# 1048574  tt5217260            8.1        85

# %%
metadata.sample()
# Out:
#             tconst  titleType  primaryTitle originalTitle isAdult startYear  \
# 6943284  tt4768334  tvEpisode  Episode #1.2  Episode #1.2       0      2015
#
#         endYear runtimeMinutes genres
# 6943284      \N             \N     \N

# %%
ratings.sample()
# Out:
#            tconst  averageRating  numVotes
# 304076  tt0585786            7.7         6

# %%
crew.tail()
# Out:
#             tconst            directors                        writers
# 9277928  tt9916848  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 9277929  tt9916850  nm5519375,nm5519454  nm6182221,nm1628284,nm2921377
# 9277930  tt9916852  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 9277931  tt9916856           nm10538645                      nm6951431
# 9277932  tt9916880            nm0996406            nm1482639,nm2586970

# %%
crew.sample()
# Out:
#             tconst directors writers
# 6826743  tt4497378        \N      \N

# %%
crew_df = pd.DataFrame(crew)

# %%
crew_df.head()
# Out:
#       tconst  directors writers
# 0  tt0000001  nm0005690      \N
# 1  tt0000002  nm0721526      \N
# 2  tt0000003  nm0721526      \N
# 3  tt0000004  nm0721526      \N
# 4  tt0000005  nm0005690      \N

# %%
crew_df.columns.tolist()
# Out:
# ['tconst', 'directors', 'writers']

# %%
output_df = pd.merge(crew, metadata, on='tconst',
                     how='inner')

# %%
output_df.head()
# Out:
#       tconst  directors writers titleType            primaryTitle  \
# 0  tt0000001  nm0005690      \N     short              Carmencita
# 1  tt0000002  nm0721526      \N     short  Le clown et ses chiens
# 2  tt0000003  nm0721526      \N     short          Pauvre Pierrot
# 3  tt0000004  nm0721526      \N     short             Un bon bock
# 4  tt0000005  nm0005690      \N     short        Blacksmith Scene
#
#             originalTitle isAdult startYear endYear runtimeMinutes genres
# 0              Carmencita       0      1894      \N              1     \N
# 1  Le clown et ses chiens       0      1892      \N              5     \N
# 2          Pauvre Pierrot       0      1892      \N              4     \N
# 3             Un bon bock       0      1892      \N             12     \N
# 4        Blacksmith Scene       0      1893      \N              1     \N

# %%
complete_df = pd.merge(output_df, ratings, on='tconst',
                      how='inner')

# %%
complete_df.head()
# Out:
#       tconst  directors writers titleType            primaryTitle  \
# 0  tt0000001  nm0005690      \N     short              Carmencita
# 1  tt0000002  nm0721526      \N     short  Le clown et ses chiens
# 2  tt0000003  nm0721526      \N     short          Pauvre Pierrot
# 3  tt0000004  nm0721526      \N     short             Un bon bock
# 4  tt0000005  nm0005690      \N     short        Blacksmith Scene
#
#             originalTitle isAdult startYear endYear runtimeMinutes genres  \
# 0              Carmencita       0      1894      \N              1     \N
# 1  Le clown et ses chiens       0      1892      \N              5     \N
# 2          Pauvre Pierrot       0      1892      \N              4     \N
# 3             Un bon bock       0      1892      \N             12     \N
# 4        Blacksmith Scene       0      1893      \N              1     \N
#
#    averageRating  numVotes
# 0            5.7      1914
# 1            5.8       259
# 2            6.5      1720
# ...

# %%
tsv_files = ['title-crew.tsv', 'title-metadata.tsv', 'title-ratings.tsv']

# %%
complete_df.to_csv(f'{file_dir}/complete.csv',
                   sep='\t', header=True,
                   index=False)

# %%
tsv_files
# Out:
# ['title-crew.tsv', 'title-metadata.tsv', 'title-ratings.tsv']

# %%
complete_df.head()
# Out:
#       tconst  directors writers titleType            primaryTitle  \
# 0  tt0000001  nm0005690      \N     short              Carmencita
# 1  tt0000002  nm0721526      \N     short  Le clown et ses chiens
# 2  tt0000003  nm0721526      \N     short          Pauvre Pierrot
# 3  tt0000004  nm0721526      \N     short             Un bon bock
# 4  tt0000005  nm0005690      \N     short        Blacksmith Scene
#
#             originalTitle isAdult startYear endYear runtimeMinutes genres  \
# 0              Carmencita       0      1894      \N              1     \N
# 1  Le clown et ses chiens       0      1892      \N              5     \N
# 2          Pauvre Pierrot       0      1892      \N              4     \N
# 3             Un bon bock       0      1892      \N             12     \N
# 4        Blacksmith Scene       0      1893      \N              1     \N
#
#    averageRating  numVotes
# 0            5.7      1914
# 1            5.8       259
# 2            6.5      1720
# ...

# %%
complete_df['titleType'] == 'movie'
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048570    False
# 1048571     True
# 1048572    False
# 1048573     True
# 1048574    False
# Name: titleType, Length: 1048575, dtype: bool

# %%
complete_df[complete_df['titleType'] == 'movie']
# Out:
#             tconst  directors                        writers titleType  \
# 8        tt0000009  nm0085156                      nm0085156     movie
# 334      tt0000502  nm0063413  nm0063413,nm0657268,nm0675388     movie
# 366      tt0000574  nm0846879                      nm0846879     movie
# 374      tt0000591  nm0141150                      nm0141150     movie
# 388      tt0000615  nm0533958            nm0092809,nm0533958     movie
# ...            ...        ...                            ...       ...
# 1048564  tt5217114  nm4904932                      nm4904932     movie
# 1048567  tt5217152  nm3461208            nm3442813,nm3461208     movie
# 1048569  tt5217178  nm4940017                      nm3586791     movie
# 1048571  tt5217198  nm4159008                      nm4159008     movie
# 1048573  tt5217256  nm4435017                      nm4435017     movie
#
#                         primaryTitle                originalTitle isAdult  \
# ...

# %%
movies_df = complete_df[complete_df['titleType'] == 'movie']
type(movies_df)
# Out:
# pandas.core.frame.DataFrame

# %%
movies_df.head()
# Out:
#         tconst  directors                        writers titleType  \
# 8    tt0000009  nm0085156                      nm0085156     movie
# 334  tt0000502  nm0063413  nm0063413,nm0657268,nm0675388     movie
# 366  tt0000574  nm0846879                      nm0846879     movie
# 374  tt0000591  nm0141150                      nm0141150     movie
# 388  tt0000615  nm0533958            nm0092809,nm0533958     movie
#
#                     primaryTitle                originalTitle isAdult  \
# 8                     Miss Jerry                   Miss Jerry       0
# 334                     Bohemios                     Bohemios       0
# 366  The Story of the Kelly Gang  The Story of the Kelly Gang       0
# 374             The Prodigal Son            L'enfant prodigue       0
# 388           Robbery Under Arms           Robbery Under Arms       0
#
#     startYear endYear runtimeMinutes genres  averageRating  numVotes
# 8        1894      \N             45     \N            5.2       200
# ...

# %%
import os

# %%
movies_df.rename(columns={'old_column_name' : 'new_column_name'})
# Out:
#             tconst  directors                        writers titleType  \
# 8        tt0000009  nm0085156                      nm0085156     movie
# 334      tt0000502  nm0063413  nm0063413,nm0657268,nm0675388     movie
# 366      tt0000574  nm0846879                      nm0846879     movie
# 374      tt0000591  nm0141150                      nm0141150     movie
# 388      tt0000615  nm0533958            nm0092809,nm0533958     movie
# ...            ...        ...                            ...       ...
# 1048564  tt5217114  nm4904932                      nm4904932     movie
# 1048567  tt5217152  nm3461208            nm3442813,nm3461208     movie
# 1048569  tt5217178  nm4940017                      nm3586791     movie
# 1048571  tt5217198  nm4159008                      nm4159008     movie
# 1048573  tt5217256  nm4435017                      nm4435017     movie
#
#                         primaryTitle                originalTitle isAdult  \
# ...

# %%
movies_df.drop(['originalTitle', 'endYear', 'genres'], axis = 1, inplace=True)
# Out:
# C:\Users\saint\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
movies_df.head()
# Out:
#         tconst  directors                        writers titleType  \
# 8    tt0000009  nm0085156                      nm0085156     movie
# 334  tt0000502  nm0063413  nm0063413,nm0657268,nm0675388     movie
# 366  tt0000574  nm0846879                      nm0846879     movie
# 374  tt0000591  nm0141150                      nm0141150     movie
# 388  tt0000615  nm0533958            nm0092809,nm0533958     movie
#
#                     primaryTitle isAdult startYear runtimeMinutes  \
# 8                     Miss Jerry       0      1894             45
# 334                     Bohemios       0      1905            100
# 366  The Story of the Kelly Gang       0      1906             70
# 374             The Prodigal Son       0      1907             90
# 388           Robbery Under Arms       0      1907             \N
#
#      averageRating  numVotes
# 8              5.2       200
# 334            3.7        14
# 366            6.0       784
# 374            4.0        19
# ...

# %%
movies_df.rename({'Tconst':'tconst',
                 'directors':'Director(s)',
                 'writers':'Writer(s)',
                 'titleType':'Type',
                 'primaryTitle':'Title',
                 'isAdult':'Adult',
                 'startYear':'Year',
                 'runtimeMinutes':'Minutes',
                 'averageRating':'Rating',
                 'numVotes':'Votes'}, axis='columns', inplace=True)
# Out:
# C:\Users\saint\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
movies_df.head()
# Out:
#         tconst Director(s)                      Writer(s)   Type  \
# 8    tt0000009   nm0085156                      nm0085156  movie
# 334  tt0000502   nm0063413  nm0063413,nm0657268,nm0675388  movie
# 366  tt0000574   nm0846879                      nm0846879  movie
# 374  tt0000591   nm0141150                      nm0141150  movie
# 388  tt0000615   nm0533958            nm0092809,nm0533958  movie
#
#                            Title Adult  Year Minutes  Rating  Votes
# 8                     Miss Jerry     0  1894      45     5.2    200
# 334                     Bohemios     0  1905     100     3.7     14
# 366  The Story of the Kelly Gang     0  1906      70     6.0    784
# 374             The Prodigal Son     0  1907      90     4.0     19
# 388           Robbery Under Arms     0  1907      \N     4.1     23

# %%
f'{file_dir}movies.csv'
# Out:
# 'C:/Users/saint/OneDrive/Desktop/DataClass/movies_portfoliomovies.csv'

# %%
clean_movies_df = movies_df.sort_values(by=['Votes','Rating'], ascending=False)

# %%
clean_movies_df.head()
# Out:
#            tconst Director(s)                                Writer(s)   Type  \
# 82489   tt0111161   nm0001104                      nm0000175,nm0001104  movie
# 251203  tt0468569   nm0634240  nm0634300,nm0634240,nm0275286,nm0004170  movie
# 633907  tt1375666   nm0634240                                nm0634240  movie
# 99097   tt0137523   nm0000399                      nm0657333,nm0880243  movie
# 81396   tt0109830   nm0000709                      nm0343165,nm0744839  movie
#
#                            Title Adult  Year Minutes  Rating    Votes
# 82489   The Shawshank Redemption     0  1994     142     9.3  2647137
# 251203           The Dark Knight     0  2008     152     9.0  2619082
# 633907                 Inception     0  2010     148     8.8  2321244
# 99097                 Fight Club     0  1999     139     8.8  2091999
# 81396               Forrest Gump     0  1994     142     8.8  2049732

# %%
final_df = clean_movies_df.reindex(columns=['tconst', 'Rating', 'Votes', 'Type', 'Year', 'Title','Adult', 'Minutes'])

# %%
final_df.head()
# Out:
#            tconst  Rating    Votes   Type  Year                     Title  \
# 82489   tt0111161     9.3  2647137  movie  1994  The Shawshank Redemption
# 251203  tt0468569     9.0  2619082  movie  2008           The Dark Knight
# 633907  tt1375666     8.8  2321244  movie  2010                 Inception
# 99097   tt0137523     8.8  2091999  movie  1999                Fight Club
# 81396   tt0109830     8.8  2049732  movie  1994              Forrest Gump
#
#        Adult Minutes
# 82489      0     142
# 251203     0     152
# 633907     0     148
# 99097      0     139
# 81396      0     142

# %%
final_df.to_csv('movies.csv', index=False)

# %%
import psycopg2
from sqlalchemy import create_engine
from config import db_password

# %%
 db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/movies_port"

# %%
engine = create_engine(db_string)

# %%
final_df.to_sql(name='final', if_exists='replace', con=engine)

# %%
rows_imported = 0
