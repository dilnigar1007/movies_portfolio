# %%
import tweepy
import configparser
import pandas as pd
from config import *

# %%
#read config

# config = configparser.ConfigParser()
# config.read('config.ini')

# api_key = config['twitter']['api_key']
# api_key_secret = config['twitter']['api_key_secret']

# access_token = config['twitter']['access_token']
# access_token_secret = config['Twitter']['access_token_secret']

# %%
# #authentication

auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

public_tweets = api.home_timeline()

# %%
# #create dataframe

columns = ['Time', 'User', 'Tweet']
data = []
for tweet in public_tweets:
     data.append([tweet.created_at, tweet.user.screen_name, tweet.text])

df = pd.DataFrame(data, columns=columns)

df.to_csv('tweets.csv')

# %%
df
# sentiment analysis 
# manual classification 
# git ingnore config.py
# Out:
#                         Time          User  \
# 0  2022-11-10 03:11:08+00:00  WhistleBlitz
# 1  2022-11-10 03:02:04+00:00  WhistleBlitz
# 2  2022-11-10 02:50:03+00:00  KingFrench23
# 3  2022-11-10 02:16:01+00:00  WhistleBlitz
# 4  2022-11-10 02:07:39+00:00  WhistleBlitz
# 5  2022-11-10 01:03:57+00:00  WhistleBlitz
# 6  2022-11-10 00:51:18+00:00  WhistleBlitz
# 7  2022-11-10 00:47:30+00:00  KingFrench23
# 8  2022-11-10 00:15:00+00:00  WhistleBlitz
# 9  2022-11-10 00:01:12+00:00  WhistleBlitz
# 10 2022-11-09 23:54:46+00:00  WhistleBlitz
# 11 2022-11-09 23:08:14+00:00  WhistleBlitz
# 12 2022-11-09 23:00:06+00:00         NBA2K
# 13 2022-11-09 22:46:23+00:00  WhistleBlitz
# 14 2022-11-09 22:16:46+00:00    syannjabae
# 15 2022-11-09 21:36:24+00:00  WhistleBlitz
# 16 2022-11-09 21:17:41+00:00  WhistleBlitz
# 17 2022-11-09 21:17:36+00:00  WhistleBlitz
# 18 2022-11-09 21:14:00+00:00  WhistleBlitz
#
#                                                 Tweet
# 0        RT @NoContextClips_: https://t.co/dBcgqvAY8h
# 1   RT @DunkLeague: THAT'S A WRAP ON EPISODE 1 OF ...
# 2   Why do people just wake up in life to complain...
# 3   RT @WhistleSports: TAP IN @caffeine 🫡 \n\n#DUN...
# 4   RT @WhistleSports: IT’S TIME FOR #DUNKBATTLE 🚨...
# 5   RT @DunkLeague: 🚨 #Dunkbattle begins in 1 hour...
# 6   RT @HoopsVids: Franz is smooth like 🧈 as he de...
# 7   Just followed everyone now lets get an actives...
# 8   That 2000s @ChicagoBears defense was ELITE 🐻 h...
# 9   RT @WhistleSports: Watch at home or the stadiu...
# 10  RT @WhistleSports: After a historic season @Th...
# 11  RT @WhistleSports: BOL BOL CLAMPS ON LUKA http...
# 12  Play as @JackHarlow in MyTEAM tomorrow! https:...
# 13  RT @TheRealA_Jay: Man... You really had to be ...
# 14                           I feel so bad for Cole☹️
# 15                          RT @DaOtherKevSmith: king
# 16  RT @AndrewWhitworth: Excited I got to partner ...
# 17  RT @TG3II: Excited I got to partner with @Coro...
# 18  A legendary offense. \n\nFew compare to The Gr...
